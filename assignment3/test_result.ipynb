# %%
import numpy as np
from numpy import array
import matplotlib.pyplot as plt

from utils import ackley_f, weierstrass_f
from CSO_algorithm import cuckoo_search
from BAT_algorithm import bat_algorithm
from FP_algorithm import flower_pollination

# %% [markdown]
# # 1. Cuckoo Search

# %% [markdown]
# ## 1.1. Ackley function

# %%
cso_ackley_10dim = cuckoo_search(function=ackley_f)
cso_ackley_20dim = cuckoo_search(function=ackley_f, dimension=20)

# %%
all_values_list_cso_ackley_10d = []
all_values_list_cso_ackley_20d = []

# %%
for i in range(20):
    values, points = cso_ackley_10dim.forward(350)
    all_values_list_cso_ackley_10d.append(array(values))
# Out:
# ...
# 100%|██████████| 350/350 [00:02<00:00, 133.63it/s]

# %%
for i in range(20):
    values, points = cso_ackley_20dim.forward(500)
    all_values_list_cso_ackley_20d.append(array(values))
# Out:
# ...
# 100%|██████████| 500/500 [00:05<00:00, 89.33it/s]

# %%
all_values_matrix_cso_ackley_10d = np.row_stack(all_values_list_cso_ackley_10d) # array(number of test, number of iteration)

max_line_cso_ackley_10d = np.max(all_values_matrix_cso_ackley_10d, axis=0)
mean_line_cso_ackley_10d = np.mean(all_values_matrix_cso_ackley_10d, axis=0)
min_line_cso_ackley_10d = np.min(all_values_matrix_cso_ackley_10d, axis=0)

all_values_matrix_cso_ackley_20d = np.row_stack(all_values_list_cso_ackley_20d) # array(number of test, number of iteration)

max_line_cso_ackley_20d = np.max(all_values_matrix_cso_ackley_20d, axis=0)
mean_line_cso_ackley_20d = np.mean(all_values_matrix_cso_ackley_20d, axis=0)
min_line_cso_ackley_20d = np.min(all_values_matrix_cso_ackley_20d, axis=0)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(351), mean_line_cso_ackley_10d)
plt.fill_between(range(351), min_line_cso_ackley_10d, max_line_cso_ackley_10d, color="b", alpha=0.1, label="dimension-10")

plt.plot(range(501), mean_line_cso_ackley_20d)
plt.fill_between(range(501), min_line_cso_ackley_20d, max_line_cso_ackley_20d, color="r", alpha=0.1, label="dimension-20")
plt.xlabel("Number of iterations", weight="bold", size=12)
plt.ylabel("function values", weight="bold", size=12)
plt.title("Ackley function", weight="bold", size=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.2. Weierstrass function

# %%
cso_weierstrass_10dim = cuckoo_search(function=weierstrass_f)
cso_weierstrass_20dim = cuckoo_search(function=weierstrass_f, dimension=20)

# %%
all_values_list_cso_weierstrass_10d = []
all_values_list_cso_weierstrass_20d = []

# %%
for i in range(20):
    values, points = cso_weierstrass_10dim.forward(150)
    all_values_list_cso_weierstrass_10d.append(array(values))
# Out:
# ...
# 100%|██████████| 150/150 [00:05<00:00, 25.59it/s]

# %%
for i in range(20):
    values, points = cso_weierstrass_20dim.forward(1000)
    all_values_list_cso_weierstrass_20d.append(array(values))
# Out:
# ...
# 100%|██████████| 1000/1000 [00:53<00:00, 18.82it/s]

# %%
all_values_matrix_cso_weierstrass_10d = np.row_stack(all_values_list_cso_weierstrass_10d) # array(number of test, number of iteration)

max_line_cso_aweierstrass_10d = np.max(all_values_matrix_cso_weierstrass_10d, axis=0)
mean_line_cso_weierstrass_10d = np.mean(all_values_matrix_cso_weierstrass_10d, axis=0)
min_line_cso_weierstrass_10d = np.min(all_values_matrix_cso_weierstrass_10d, axis=0)

all_values_matrix_cso_weierstrass_20d = np.row_stack(all_values_list_cso_weierstrass_20d) # array(number of test, number of iteration)

max_line_cso_weierstrass_20d = np.max(all_values_matrix_cso_weierstrass_20d, axis=0)
mean_line_cso_weierstrass_20d = np.mean(all_values_matrix_cso_weierstrass_20d, axis=0)
min_line_cso_weierstrass_20d = np.min(all_values_matrix_cso_weierstrass_20d, axis=0)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(151), mean_line_cso_weierstrass_10d)
plt.fill_between(range(151), min_line_cso_weierstrass_10d, max_line_cso_aweierstrass_10d, color="b", alpha=0.1, label="dimension-10")

plt.plot(range(1001), mean_line_cso_weierstrass_20d)
plt.fill_between(range(1001), min_line_cso_weierstrass_20d, max_line_cso_weierstrass_20d, color="r", alpha=0.1, label="dimension-20")
plt.xlabel("Number of iterations", weight="bold", size=12)
plt.ylabel("function values", weight="bold", size=12)
plt.title("Weierstrass function", weight="bold", size=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Bat Algorithm

# %% [markdown]
# ## 2.1. Ackley function

# %%
bat_ackley_10dim = bat_algorithm(function=ackley_f)
bat_ackley_20dim = bat_algorithm(function=ackley_f, dimension=20)

# %%
all_values_list_bat_ackley_10d = []
all_values_list_bat_ackley_20d = []

# %%
for i in range(20):
    values, points = bat_ackley_10dim.forward(50)
    all_values_list_bat_ackley_10d.append(array(values))
# Out:
# ...
# 100%|██████████| 50/50 [00:00<00:00, 199.08it/s]

# %%
for i in range(20):
    values, points = bat_ackley_20dim.forward(50)
    all_values_list_bat_ackley_20d.append(array(values))
# Out:
# ...
# 100%|██████████| 50/50 [00:00<00:00, 209.79it/s]

# %%
all_values_matrix_bat_ackley_10d = np.row_stack(all_values_list_bat_ackley_10d) # array(number of test, number of iteration)

max_line_bat_ackley_10d = np.max(all_values_matrix_bat_ackley_10d, axis=0)
mean_line_bat_ackley_10d = np.mean(all_values_matrix_bat_ackley_10d, axis=0)
min_line_bat_ackley_10d = np.min(all_values_matrix_bat_ackley_10d, axis=0)

all_values_matrix_bat_ackley_20d = np.row_stack(all_values_list_bat_ackley_20d) # array(number of test, number of iteration)

max_line_bat_ackley_20d = np.max(all_values_matrix_bat_ackley_20d, axis=0)
mean_line_bat_ackley_20d = np.mean(all_values_matrix_bat_ackley_20d, axis=0)
min_line_bat_ackley_20d = np.min(all_values_matrix_bat_ackley_20d, axis=0)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(51), mean_line_bat_ackley_10d)
plt.fill_between(range(51), min_line_bat_ackley_10d, max_line_bat_ackley_10d, color="b", alpha=0.1, label="dimension-10")

plt.plot(range(51), mean_line_bat_ackley_20d)
plt.fill_between(range(51), min_line_bat_ackley_20d, max_line_bat_ackley_20d, color="r", alpha=0.1, label="dimension-20")
plt.xlabel("Number of iterations", weight="bold", size=12)
plt.ylabel("function values", weight="bold", size=12)
plt.title("Ackley function (Bat algorithm)", weight="bold", size=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.2. Weierstrass function

# %%
bat_weierstrass_10dim = bat_algorithm(function=weierstrass_f)
bat_weierstrass_20dim = bat_algorithm(function=weierstrass_f, dimension=20)

# %%
all_values_list_bat_weierstrass_10d = []
all_values_list_bat_weierstrass_20d = []

# %%
for i in range(20):
    values, points = bat_weierstrass_10dim.forward(150)
    all_values_list_bat_weierstrass_10d.append(array(values))
# Out:
# ...
# 100%|██████████| 150/150 [00:03<00:00, 49.29it/s]

# %%
for i in range(20):
    values, points = bat_weierstrass_20dim.forward(150)
    all_values_list_bat_weierstrass_20d.append(array(values))
# Out:
# ...
# 100%|██████████| 150/150 [00:03<00:00, 45.69it/s]

# %%
all_values_matrix_bat_weierstrass_10d = np.row_stack(all_values_list_bat_weierstrass_10d) # array(number of test, number of iteration)

max_line_bat_aweierstrass_10d = np.max(all_values_matrix_bat_weierstrass_10d, axis=0)
mean_line_bat_weierstrass_10d = np.mean(all_values_matrix_bat_weierstrass_10d, axis=0)
min_line_bat_weierstrass_10d = np.min(all_values_matrix_bat_weierstrass_10d, axis=0)

all_values_matrix_bat_weierstrass_20d = np.row_stack(all_values_list_bat_weierstrass_20d) # array(number of test, number of iteration)

max_line_bat_weierstrass_20d = np.max(all_values_matrix_bat_weierstrass_20d, axis=0)
mean_line_bat_weierstrass_20d = np.mean(all_values_matrix_bat_weierstrass_20d, axis=0)
min_line_bat_weierstrass_20d = np.min(all_values_matrix_bat_weierstrass_20d, axis=0)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(151), mean_line_bat_weierstrass_10d)
plt.fill_between(range(151), min_line_bat_weierstrass_10d, max_line_bat_aweierstrass_10d, color="b", alpha=0.1, label="dimension-10")

plt.plot(range(151), mean_line_bat_weierstrass_20d)
plt.fill_between(range(151), min_line_bat_weierstrass_20d, max_line_bat_weierstrass_20d, color="r", alpha=0.1, label="dimension-20")
plt.xlabel("Number of iterations", weight="bold", size=12)
plt.ylabel("function values", weight="bold", size=12)
plt.title("Weierstrass function (Bat algorithm)", weight="bold", size=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Flower Pollination

# %% [markdown]
# ## 3.1. Ackley function

# %%
fpa_ackley_10dim = flower_pollination(function=ackley_f)
fpa_ackley_20dim = flower_pollination(function=ackley_f, dimension=20)

# %%
all_values_list_fpa_ackley_10d = []
all_values_list_fpa_ackley_20d = []

# %%
for i in range(20):
    values, points = fpa_ackley_10dim.forward(350)
    all_values_list_fpa_ackley_10d.append(array(values))
# Out:
# ...
# 100%|██████████| 350/350 [00:01<00:00, 278.40it/s]

# %%
for i in range(20):
    values, points = fpa_ackley_20dim.forward(350)
    all_values_list_fpa_ackley_20d.append(array(values))
# Out:
# ...
# 100%|██████████| 350/350 [00:01<00:00, 283.42it/s]

# %%
all_values_matrix_fpa_ackley_10d = np.row_stack(all_values_list_fpa_ackley_10d) # array(number of test, number of iteration)

max_line_fpa_ackley_10d = np.max(all_values_matrix_fpa_ackley_10d, axis=0)
mean_line_fpa_ackley_10d = np.mean(all_values_matrix_fpa_ackley_10d, axis=0)
min_line_fpa_ackley_10d = np.min(all_values_matrix_fpa_ackley_10d, axis=0)

all_values_matrix_fpa_ackley_20d = np.row_stack(all_values_list_fpa_ackley_20d) # array(number of test, number of iteration)

max_line_fpa_ackley_20d = np.max(all_values_matrix_fpa_ackley_20d, axis=0)
mean_line_fpa_ackley_20d = np.mean(all_values_matrix_fpa_ackley_20d, axis=0)
min_line_fpa_ackley_20d = np.min(all_values_matrix_fpa_ackley_20d, axis=0)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(351), mean_line_fpa_ackley_10d)
plt.fill_between(range(351), min_line_fpa_ackley_10d, max_line_fpa_ackley_10d, color="b", alpha=0.1, label="dimension-10")

plt.plot(range(351), mean_line_fpa_ackley_20d)
plt.fill_between(range(351), min_line_fpa_ackley_20d, max_line_fpa_ackley_20d, color="r", alpha=0.1, label="dimension-20")
plt.xlabel("Number of iterations", weight="bold", size=12)
plt.ylabel("function values", weight="bold", size=12)
plt.title("Ackley function (Flower pollination)", weight="bold", size=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.2. Weierstrass function

# %%
fpa_weierstrass_10dim = flower_pollination(function=weierstrass_f)
fpa_weierstrass_20dim = flower_pollination(function=weierstrass_f, dimension=20)

# %%
all_values_list_fpa_weierstrass_10d = []
all_values_list_fpa_weierstrass_20d = []

# %%
for i in range(20):
    values, points = fpa_weierstrass_10dim.forward(350)
    all_values_list_fpa_weierstrass_10d.append(array(values))
# Out:
# ...
# 100%|██████████| 350/350 [00:06<00:00, 57.91it/s]

# %%
for i in range(20):
    values, points = fpa_weierstrass_20dim.forward(350)
    all_values_list_fpa_weierstrass_20d.append(array(values))
# Out:
# ...
# 100%|██████████| 350/350 [00:07<00:00, 43.77it/s]

# %%
all_values_matrix_fpa_weierstrass_10d = np.row_stack(all_values_list_fpa_weierstrass_10d) # array(number of test, number of iteration)

max_line_fpa_aweierstrass_10d = np.max(all_values_matrix_fpa_weierstrass_10d, axis=0)
mean_line_fpa_weierstrass_10d = np.mean(all_values_matrix_fpa_weierstrass_10d, axis=0)
min_line_fpa_weierstrass_10d = np.min(all_values_matrix_fpa_weierstrass_10d, axis=0)

all_values_matrix_fpa_weierstrass_20d = np.row_stack(all_values_list_fpa_weierstrass_20d) # array(number of test, number of iteration)

max_line_fpa_weierstrass_20d = np.max(all_values_matrix_fpa_weierstrass_20d, axis=0)
mean_line_fpa_weierstrass_20d = np.mean(all_values_matrix_fpa_weierstrass_20d, axis=0)
min_line_fpa_weierstrass_20d = np.min(all_values_matrix_fpa_weierstrass_20d, axis=0)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(351), mean_line_fpa_weierstrass_10d)
plt.fill_between(range(351), min_line_fpa_weierstrass_10d, max_line_fpa_aweierstrass_10d, color="b", alpha=0.1, label="dimension-10")

plt.plot(range(351), mean_line_fpa_weierstrass_20d)
plt.fill_between(range(351), min_line_fpa_weierstrass_20d, max_line_fpa_weierstrass_20d, color="r", alpha=0.1, label="dimension-20")
plt.xlabel("Number of iterations", weight="bold", size=12)
plt.ylabel("function values", weight="bold", size=12)
plt.title("Weierstrass function (Flower pollination)", weight="bold", size=15)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
